# %% [markdown]
# Question 1
# Null Hypothesis (H₀)
#
# The null hypothesis states that there is no effect, no difference, or no change in the population.
#
# Importance:
#
# It is the default assumption
#
# Provides a basis for statistical testing
#
# Helps determine whether observed results are due to chance
#
# Question 2
# Significance Level (α)
#
# The significance level (α) is the probability of rejecting the null hypothesis when it is actually true.
#
# Common values: 0.05, 0.01
#
# α = 0.05 means a 5% risk of making a Type I error
#
# Question 3
# Type I vs Type II Errors
# Error Type	Meaning
# Type I Error	Rejecting a true null hypothesis
# Type II Error	Failing to reject a false null hypothesis
# Question 4
# One-tailed vs Two-tailed Test
#
# One-tailed Test
#
# Tests for a difference in one direction
#
# Example: “Training improves productivity”
#
# Two-tailed Test
#
# Tests for a difference in both directions
#
# Example: “Average time is not equal to 10 minutes”
#
# Question 5
# Testing the Company’s Claim (t-test)
#
# Given:
#
# μ = 10
#
# x̄ = 12
#
# s = 3
#
# n = 9
#
# α = 0.05
#
# Step 1: Hypotheses
#
# H₀: μ = 10
#
# H₁: μ ≠ 10
#
# Step 2: Test Statistic
#
# 𝑡
# =
# 12
# −
# 10
# 3
# /
# 9
# =
# 2
# 1
# =
# 2
# t=
# 3/
# 9
# 	​
#
# 12−10
# 	​
#
# =
# 1
# 2
# 	​
#
# =2
#
# Step 3: Critical Value
#
# df = 8
#
# t₀.₀₂₅ ≈ 2.306
#
# Step 4: Decision
#
# |t| < critical value → Fail to reject H₀
#
# Conclusion:
# There is insufficient evidence to reject the company’s claim.
#
# Question 6
# Z-test vs t-test
#
# Use a Z-test when:
#
# Sample size ≥ 30
#
# Population standard deviation is known
#
# Data is normally distributed
#
# Use a t-test when:
#
# Sample size < 30
#
# Population standard deviation is unknown
#
# Question 7
# Paired t-test (Training Program)
# Employee	Before	After
# 1	50	55
# 2	60	65
# 3	58	59
# 4	55	58
# 5	62	63
# 6	56	59
#
# Differences: [5, 5, 1, 3, 1, 3]
#
# Mean difference = 3
#
# Standard deviation ≈ 1.79
#
# n = 6
#
# 𝑡
# =
# 3
# 1.79
# /
# 6
# ≈
# 4.11
# t=
# 1.79/
# 6
# 	​
#
# 3
# 	​
#
# ≈4.11
#
# Critical value (df = 5, α = 0.05) ≈ 2.571
#
# Decision: Reject H₀
#
# Conclusion:
# Training significantly improved productivity.
#
# Question 8
# Chi-Square Test of Independence
# Gender	Product A	Product B	Total
# Male	40	60	100
# Female	30	20	50
# Total	70	80	150
#
# Hypotheses:
#
# H₀: Product preference is independent of gender
#
# H₁: Product preference depends on gender
#
# Calculated χ² ≈ 4.46
# Critical value (df = 1, α = 0.05) = 3.84
#
# Decision: Reject H₀
#
# Conclusion:
# Product preference depends on gender.
